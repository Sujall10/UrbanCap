# %%
import pandas as pd

# %%
SP_performance = pd.read_csv('Datas/FINAList_Hetviiii.csv')
SP_performance
# Out:
#       performance_review_id  average_rating  customer_feedback_score  \
# 0                         1             4.1                    80.81
# 1                         2             4.9                    94.63
# 2                         3             4.6                    94.86
# 3                         4             4.4                    90.34
# 4                         5             3.7                    72.84
# ...                     ...             ...                      ...
# 2965                   2966             4.6                    94.33
# 2966                   2967             4.6                    93.85
# 2967                   2968             4.3                    83.12
# 2968                   2969             4.9                    95.39
# 2969                   2970             4.2                    81.81
#
#       total_reviews  completion_rate  cancellation_rate  response_time  \
# ...

# %%
SP = pd.read_csv('Datas/SP.xls')

# %%
SP
# Out:
#       provider_id           name  gender  age  contact_number           city  \
# 0               1      Manoj Das    Male   25  +91 9235082515       Tirupati
# 1               2     Rashmi Das  Female   41  +91 7117600706  Visakhapatnam
# 2               3  Kavita Pillai  Female   21  +91 9527105942     Vijayawada
# 3               4      Arjun Das    Male   28  +91 6153112719       Itanagar
# 4               5   Suresh Gupta    Male   31  +91 7422213125         Dhubri
# ...           ...            ...     ...  ...             ...            ...
# 2965         2966    Meera Reddy  Female   30  +91 8100914487      Delhi NCR
# 2966         2967    Kavita Nair  Female   25  +91 8161631632     Chandigarh
# 2967         2968     Amit Singh    Male   28  +91 8467093044     Puducherry
# 2968         2969    Suman Verma  Female   33  +91 9815515713            Diu
# 2969         2970    Manoj Reddy    Male   37  +91 8585785220       Srinagar
#
# ...

# %%
user = pd.read_excel('Datas/userUrban.xlsx')

# %%
user
# Out:
#       user_id              name  gender  age                        email  \
# 0           0         Roy Braun    male   21          roy.braun@yahoo.com
# 1           1    Joseph Holsten    male   37   joseph.holsten@company.com
# 2           2     Wilma Mcinnis  female   48    wilma.mcinnis@company.com
# 3           3      Paula Daniel  female   23       paula.daniel@yahoo.com
# 4           4   Patricia Carson  female   44  patricia.carson@outlook.com
# ...       ...               ...     ...  ...                          ...
# 1335     1335  Albert Garroutte    male   23   albert.garroutte@gmail.com
# 1336     1336        Kim Shores  female   40       kim.shores@company.com
# 1337     1337     James Gimenez    male   28      james.gimenez@gmail.com
# 1338     1338      Viola Agosta  female   52       viola.agosta@yahoo.com
# 1339     1339    Paul Rodriguez    male   35     paul.rodriguez@yahoo.com
#
#       phone_number  location_id preferred_services preferred_time_slots  \
# ...

# %%
df_loc = pd.read_excel('Datas/Location_Table.xlsx')

# %%
df_loc
# Out:
#     LocationID                                               Name  \
# 0            1             Coimbatore International Airport (CJB)
# 1            2                          Birsa Munda Airport (IXR)
# 2            3                    Goa International Airport (GOI)
# 3            4  Sardar Vallabhbhai Patel International Airport...
# 4            5           Rajiv Gandhi International Airport (HYD)
# 5            6                             Agartala Airport (IXA)
# 6            7  Chhatrapati Shivaji Maharaj International Airp...
# 7            8                   Pune International Airport (PNQ)
# 8            9                           Vijayawada Airport (VGA)
# 9           10                              Gwalior Airport (GWL)
# 10          11             Kempegowda International Airport (BLR)
# 11          12  Lokpriya Gopinath Bordoloi International Airpo...
# 12          13                             Bilaspur Airport (PAB)
# ...

# %%
code_to_name = dict(zip(df_loc['City'], df_loc['LocationID']))
SP['LocationID'] = SP['city'].map(code_to_name)

# %%
SP.to_csv('SPP')

# %%
user.to_csv('user')

# %%
booking_history = []

# %%
used_slots = {}

# %%
# Function to create a booking record
def create_booking(user, total_bookings):
    for _ in range(total_bookings):
#         provider_id = SP['provider_id']
        provider_id = random.choice(SP['provider_id'].unique())  # Select a single provider
        service_id = random.choice(SP['service_Id'].unique())  # Select a single service
        service_location = user['location_id']  # Select a single ID from available services
        service_location = user['location_id']

        # Generate booking and service dates
        booking_date = datetime.now() - timedelta(days=random.randint(10, 180))
        service_date = booking_date + timedelta(days=random.randint(1, 7))  # Service within a week

        # Ensure provider is not booked at the same time elsewhere
        provider_id = SP['provider_id'].iloc[0]  # Fetch provider_id safely

        provider_key = (provider_id, service_date)

        if provider_key in used_slots:
            continue  # Skip booking if provider is already scheduled at that time

        used_slots[provider_key] = True  # Mark provider as booked

        # Generate booking details
        booking_status = random.choice(["Completed", "Cancelled", "Confirmed"])
        payment_status = random.choice(["Paid", "Pending", "Refunded", "Failed"])
        total_amount = round(random.uniform(500, 5000), 2)
        discount_applied = round(random.uniform(0, total_amount * 0.2), 2)  # Random discount up to 20%
        tax_amount = round(total_amount * 0.18, 2)  # 18% GST or service tax
        final_payment = round(total_amount - discount_applied + tax_amount, 2)

        booking_history.append([len(booking_history) + 1, user['user_id'], provider_id, service_id, booking_date, service_date,
                                service_location, booking_status, payment_status, total_amount,
                                discount_applied, tax_amount, final_payment])

# %%
user = pd.read_excel('Datas/userUrban.xlsx')
for _, user in user.iterrows():  # Ensure it's user_df, not user
    total_bookings = user['booking_history_count']  # Adjust this to match the actual column name
    create_booking(user, total_bookings)

# %%
from datetime import datetime, timedelta  # Import the datetime class

# %%
import random

# %%
booking_columns = ['Booking_ID', 'User_ID', 'Provider_ID', 'Service_ID', 'Booking_Date', 'Service_Date',
                   'Service_Location', 'Booking_Status', 'Payment_Status', 'Total_Amount', 
                   'Discount_Applied', 'Tax_Amount', 'Final_Payment']

# %%
booking_dfff = pd.DataFrame(booking_history, columns=booking_columns)

# %%
booking_dfff
# Out:
#        Booking_ID  User_ID  Provider_ID  Service_ID  \
# 0               1        0            1           4
# 1               2        0            1           5
# 2               3        0            1           9
# 3               4        0            1          10
# 4               5        0            1          10
# ...           ...      ...          ...         ...
# 32894       32895     1339            1           2
# 32895       32896     1339            1           9
# 32896       32897     1339            1          10
# 32897       32898     1339            1          11
# 32898       32899     1339            1           7
#
#                     Booking_Date               Service_Date  Service_Location  \
# 0     2025-01-31 14:43:34.072900 2025-02-05 14:43:34.072900                48
# 1     2025-02-03 14:43:34.073898 2025-02-07 14:43:34.073898                48
# 2     2025-02-25 14:43:34.073898 2025-02-26 14:43:34.073898                48
# ...

# %%
booking_dfff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32899 entries, 0 to 32898
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Booking_ID        32899 non-null  int64
#  1   User_ID           32899 non-null  int64
#  2   Provider_ID       32899 non-null  int64
#  3   Service_ID        32899 non-null  int64
#  4   Booking_Date      32899 non-null  datetime64[ns]
#  5   Service_Date      32899 non-null  datetime64[ns]
#  6   Service_Location  32899 non-null  int64
#  7   Booking_Status    32899 non-null  object
#  8   Payment_Status    32899 non-null  object
#  9   Total_Amount      32899 non-null  float64
#  10  Discount_Applied  32899 non-null  float64
#  11  Tax_Amount        32899 non-null  float64
#  12  Final_Payment     32899 non-null  float64
# dtypes: datetime64[ns](2), float64(4), int64(5), object(2)
# memory usage: 3.3+ MB

# %%
total_bookings = 0 
for i in user["user_id"]:
    total_bookings += len(booking_dfff[booking_dfff['User_ID'] == i])

print(total_bookings)
# Out:
# 32899

# %%
for val in user["user_id"]:  # Replace with the actual column name
    print(val)

# %%
user
# Out:
#       user_id              name  gender  age                        email  \
# 0           0         Roy Braun    male   21          roy.braun@yahoo.com
# 1           1    Joseph Holsten    male   37   joseph.holsten@company.com
# 2           2     Wilma Mcinnis  female   48    wilma.mcinnis@company.com
# 3           3      Paula Daniel  female   23       paula.daniel@yahoo.com
# 4           4   Patricia Carson  female   44  patricia.carson@outlook.com
# ...       ...               ...     ...  ...                          ...
# 1335     1335  Albert Garroutte    male   23   albert.garroutte@gmail.com
# 1336     1336        Kim Shores  female   40       kim.shores@company.com
# 1337     1337     James Gimenez    male   28      james.gimenez@gmail.com
# 1338     1338      Viola Agosta  female   52       viola.agosta@yahoo.com
# 1339     1339    Paul Rodriguez    male   35     paul.rodriguez@yahoo.com
#
#       phone_number  location_id preferred_services preferred_time_slots  \
# ...

# %%
len(booking_dfff[booking_dfff['User_ID']==1336])
# Out:
# 28

# %%
booking_dfff
# Out:
#        Booking_ID  User_ID  Provider_ID  Service_ID  \
# 0               1        0            1           4
# 1               2        0            1           5
# 2               3        0            1           9
# 3               4        0            1          10
# 4               5        0            1          10
# ...           ...      ...          ...         ...
# 32894       32895     1339            1           2
# 32895       32896     1339            1           9
# 32896       32897     1339            1          10
# 32897       32898     1339            1          11
# 32898       32899     1339            1           7
#
#                     Booking_Date               Service_Date  Service_Location  \
# 0     2025-01-31 14:43:34.072900 2025-02-05 14:43:34.072900                48
# 1     2025-02-03 14:43:34.073898 2025-02-07 14:43:34.073898                48
# 2     2025-02-25 14:43:34.073898 2025-02-26 14:43:34.073898                48
# ...

# %%
booking_dfff.to_csv('Booking.csv')

# %%
x = user[user['location_id']==1]

# %%
x['user_id'].unique()
# Out:
# array([ 138,  166,  455,  514,  556,  660,  698,  704,  809,  814,  864,
#         883,  972,  975, 1037, 1104, 1127, 1154, 1157, 1173, 1177, 1191,
#        1194, 1284, 1293, 1332], dtype=int64)

# %%
y = SP[(SP['LocationID'] == 1) & (SP['service_Id'] == 2)]

# %%
y
# Out:
#      provider_id         name  gender  age  contact_number        city  \
# 310          311   Pooja Iyer  Female   22  +91 7424747287  Coimbatore
# 364          365   Pooja Iyer  Female   41  +91 9439095596  Coimbatore
# 418          419  Deepika Das  Female   30  +91 6641144407  Coimbatore
# 472          473    Amit Nair    Male   30  +91 8942897330  Coimbatore
# 526          527  Neha Pillai  Female   41  +91 9319818881  Coimbatore
#
#     Service Type Specialization        Certifications  Experience Years  \
# 310       Beauty            Spa  Certified Beautician              16.0
# 364       Beauty            Spa    Spa Therapy Course              21.0
# 418       Beauty            Spa    Spa Therapy Course               2.0
# 472       Beauty            Spa  Certified Beautician              10.0
# 526       Beauty            Spa  Certified Beautician               8.0
#
#     Working Hours Preferred Work Days  service_Id  LocationID
# ...

# %%
past_booking = pd.read_csv('Datas/Final_Dates_Formatted_Booking.csv')

# %%
past = past_booking.drop(columns={'Unnamed: 0'})

# %%
# past['Booking_Date'] = booking_dfff['Booking_Date']

# %%
# past['Service_Date'] = booking_dfff['Service_Date']
past
# Out:
#        Booking_ID  User_ID  Provider_ID  Service_ID Booking_Date Service_Date  \
# 0           30644     1244            1           1   24-01-2024   27-01-2024
# 1           18682      755            1           1   22-01-2024   30-01-2024
# 2           31026     1259            1           1   23-01-2024   02-02-2024
# 3           21286      866            1           1   30-01-2024   06-02-2024
# 4            6333      255            1           1   02-02-2024   07-02-2024
# ...           ...      ...          ...         ...          ...          ...
# 33031       25763     1039         2700          10   17-05-2021   26-05-2021
# 33032       27857     1129         2700          10   22-05-2021   29-05-2021
# 33033       26493     1065         2700          10   29-05-2021   01-06-2021
# 33034       13772      558         2700          10   29-05-2021   05-06-2021
# 33035       19994      806         2700          10   30-05-2021   06-06-2021
#
# ...

# %%
past
# Out:
#        Booking_ID  User_ID  Provider_ID  Service_ID Booking_Date Service_Date  \
# 0           30644     1244            1           1   24-01-2024   27-01-2024
# 1           18682      755            1           1   22-01-2024   30-01-2024
# 2           31026     1259            1           1   23-01-2024   02-02-2024
# 3           21286      866            1           1   30-01-2024   06-02-2024
# 4            6333      255            1           1   02-02-2024   07-02-2024
# ...           ...      ...          ...         ...          ...          ...
# 33031       25763     1039         2700          10   17-05-2021   26-05-2021
# 33032       27857     1129         2700          10   22-05-2021   29-05-2021
# 33033       26493     1065         2700          10   29-05-2021   01-06-2021
# 33034       13772      558         2700          10   29-05-2021   05-06-2021
# 33035       19994      806         2700          10   30-05-2021   06-06-2021
#
# ...

# %%
past[past['User_ID']==0].shape
# Out:
# (28, 15)

# %%
y = SP[(SP['LocationID'] == 1) & (SP['service_Id'] == 10)]

# %%
y
# Out:
#       provider_id           name  gender  age  contact_number        city  \
# 2470         2471    Swati Reddy  Female   30  +91 8627386226  Coimbatore
# 2524         2525  Kavita Pillai  Female   32  +91 9308368044  Coimbatore
# 2578         2579     Sanjay Das    Male   39  +91 8619706624  Coimbatore
# 2632         2633   Kavita Gupta  Female   30  +91 6389868201  Coimbatore
# 2686         2687    Pooja Reddy  Female   41  +91 6334976542  Coimbatore
#
#      Service Type            Specialization  \
# 2470     Plumbing  Repair Any Damaged Items
# 2524     Plumbing  Repair Any Damaged Items
# 2578     Plumbing  Repair Any Damaged Items
# 2632     Plumbing  Repair Any Damaged Items
# 2686     Plumbing  Repair Any Damaged Items
#
#                          Certifications  Experience Years Working Hours  \
# 2470  Certified Pipe Fitting Specialist              15.0  11 AM - 8 PM
# 2524  Certified Pipe Fitting Specialist               5.0  11 AM - 8 PM
# ...

# %%
x = user[user['location_id']==1]

# %%
user
# Out:
#       user_id              name  gender  age                        email  \
# 0           0         Roy Braun    male   21          roy.braun@yahoo.com
# 1           1    Joseph Holsten    male   37   joseph.holsten@company.com
# 2           2     Wilma Mcinnis  female   48    wilma.mcinnis@company.com
# 3           3      Paula Daniel  female   23       paula.daniel@yahoo.com
# 4           4   Patricia Carson  female   44  patricia.carson@outlook.com
# ...       ...               ...     ...  ...                          ...
# 1335     1335  Albert Garroutte    male   23   albert.garroutte@gmail.com
# 1336     1336        Kim Shores  female   40       kim.shores@company.com
# 1337     1337     James Gimenez    male   28      james.gimenez@gmail.com
# 1338     1338      Viola Agosta  female   52       viola.agosta@yahoo.com
# 1339     1339    Paul Rodriguez    male   35     paul.rodriguez@yahoo.com
#
#       phone_number  location_id preferred_services preferred_time_slots  \
# ...

# %%
x['user_id'].unique()
# Out:
# array([ 138,  166,  455,  514,  556,  660,  698,  704,  809,  814,  864,
#         883,  972,  975, 1037, 1104, 1127, 1154, 1157, 1173, 1177, 1191,
#        1194, 1284, 1293, 1332], dtype=int64)

# %%
user
# Out:
#       user_id              name  gender  age                        email  \
# 0           0         Roy Braun    male   21          roy.braun@yahoo.com
# 1           1    Joseph Holsten    male   37   joseph.holsten@company.com
# 2           2     Wilma Mcinnis  female   48    wilma.mcinnis@company.com
# 3           3      Paula Daniel  female   23       paula.daniel@yahoo.com
# 4           4   Patricia Carson  female   44  patricia.carson@outlook.com
# ...       ...               ...     ...  ...                          ...
# 1335     1335  Albert Garroutte    male   23   albert.garroutte@gmail.com
# 1336     1336        Kim Shores  female   40       kim.shores@company.com
# 1337     1337     James Gimenez    male   28      james.gimenez@gmail.com
# 1338     1338      Viola Agosta  female   52       viola.agosta@yahoo.com
# 1339     1339    Paul Rodriguez    male   35     paul.rodriguez@yahoo.com
#
#       phone_number  location_id preferred_services preferred_time_slots  \
# ...

# %%
past
# Out:
#        Booking_ID  User_ID  Provider_ID  Service_ID Booking_Date Service_Date  \
# 0           30644     1244            1           1   24-01-2024   27-01-2024
# 1           18682      755            1           1   22-01-2024   30-01-2024
# 2           31026     1259            1           1   23-01-2024   02-02-2024
# 3           21286      866            1           1   30-01-2024   06-02-2024
# 4            6333      255            1           1   02-02-2024   07-02-2024
# ...           ...      ...          ...         ...          ...          ...
# 33031       25763     1039         2700          10   17-05-2021   26-05-2021
# 33032       27857     1129         2700          10   22-05-2021   29-05-2021
# 33033       26493     1065         2700          10   29-05-2021   01-06-2021
# 33034       13772      558         2700          10   29-05-2021   05-06-2021
# 33035       19994      806         2700          10   30-05-2021   06-06-2021
#
# ...

# %%
past.to_csv("Past_Booking.csv")

# %%
past['Provider_ID'].max()
# Out:
# 2700
